# %% [markdown]
# <a href="https://colab.research.google.com/github/MwongeliK/DATA-VISUALIZATION/blob/main/PANDAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("index.csv")

# %%
df.head()
df.shape
df.tail()
# Out:
#      A  B   C   D  E  F      G      H      I     J  K  L
# 252  C  A   0  60  ?  0   COIL  0.799  609.0     0  0  3
# 253  C  R   6   0  ?  0  SHEET  1.000  610.0  4880  0  3
# 254  C  A   0  50  ?  0   COIL  0.600   20.0     0  0  3
# 255  C  K  45   0  ?  0   COIL  0.600  900.0     0  0  3
# 256  C  R   6   0  ?  0  SHEET  1.000  610.0   762  0  3

# %%
df.iloc[:,2:3]
# Out:
#       C
# 0     8
# 1     0
# 2     0
# 3     0
# 4     0
# ..   ..
# 252   0
# 253   6
# 254   0
# 255  45
# 256   6
#
# [257 rows x 1 columns]

# %%
df.iloc[:,-2:]
# Out:
#      K  L
# 0    0  3
# 1    0  3
# 2    0  3
# 3    0  3
# 4    0  3
# ..  .. ..
# 252  0  3
# 253  0  3
# 254  0  3
# 255  0  3
# 256  0  3
#
# [257 rows x 2 columns]

# %%
df.iloc[-10:,2:]
# Out:
#       C   D  E  F      G      H       I     J  K  L
# 247   0   0  S  0   COIL  0.901   966.0     0  0  3
# 248   0   0  S  0  SHEET  0.700   610.0   762  0  3
# 249   0   0  S  0   COIL  0.800    75.0     0  0  3
# 250   0   0  S  0  SHEET  0.700  1320.0   762  0  3
# 251   0  50  ?  0  SHEET  0.601  1250.0   762  0  3
# 252   0  60  ?  0   COIL  0.799   609.0     0  0  3
# 253   6   0  ?  0  SHEET  1.000   610.0  4880  0  3
# 254   0  50  ?  0   COIL  0.600    20.0     0  0  3
# 255  45   0  ?  0   COIL  0.600   900.0     0  0  3
# 256   6   0  ?  0  SHEET  1.000   610.0   762  0  3

# %%
df.head(5)
# Out:
#    A  B  C   D  E  F      G      H       I    J  K  L
# 0  C  A  8   0  S  0   COIL  0.700   610.0    0  0  3
# 1  C  R  0   0  S  0   COIL  3.200   610.0    0  0  3
# 2  C  R  0   0  S  0  SHEET  0.700  1300.0  762  0  3
# 3  C  A  0  60  ?  0   COIL  2.801   385.1    0  0  3
# 4  C  A  0  60  ?  0  SHEET  0.801   255.0  269  0  3

# %%
df.sort_values(by='C')
df[:5]
# Out:
#    A  B  C   D  E  F      G      H       I    J  K  L
# 0  C  A  8   0  S  0   COIL  0.700   610.0    0  0  3
# 1  C  R  0   0  S  0   COIL  3.200   610.0    0  0  3
# 2  C  R  0   0  S  0  SHEET  0.700  1300.0  762  0  3
# 3  C  A  0  60  ?  0   COIL  2.801   385.1    0  0  3
# 4  C  A  0  60  ?  0  SHEET  0.801   255.0  269  0  3

# %%
#creating dummy dataframes
df1=pd.DataFrame(
    {'A':['A0','A1','A2','A3'],
     'B':['B0','B1','B2','B3'],
     'C':['C0','C1','C2','C3'],
     'D':['D0','D1','D2','D3']},
     index=[0,1,2,3])
df2=pd.DataFrame(
    {'A':['A4','A5','A6','A7'],
     'B':['B4','B5','B6','B7'],
     'C':['C4','C5','C6','C7'],
     'D':['D4','D5','D6','D7']},
     index=[4,5,6,7])
df3=pd.DataFrame(
    {'A':['A8','A9','A10','A11'],
     'B':['B8','B9','B10','B11'],
     'C':['C8','C9','C10','C11'],
     'D':['D8','D9','D10','D11']},
     index=[8,9,10,11])

# %%
#CONCATENATION OF THE DATAFRAMES CREATED ABOVE AND GIVING KEYS TO THE DATA FRAME
result = pd.concat([df1,df2,df3],keys=['X','Y','Z'])
result
# Out:
#         A    B    C    D
# X 0    A0   B0   C0   D0
#   1    A1   B1   C1   D1
#   2    A2   B2   C2   D2
#   3    A3   B3   C3   D3
# Y 4    A4   B4   C4   D4
#   5    A5   B5   C5   D5
#   6    A6   B6   C6   D6
#   7    A7   B7   C7   D7
# Z 8    A8   B8   C8   D8
#   9    A9   B9   C9   D9
#   10  A10  B10  C10  D10
#   11  A11  B11  C11  D11

# %%
#EXTRACTING A SINGLE DATAFRAME USING KEYS
result.loc['Y']
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
#USING INNER AND OUTER JOIN
df4=pd.DataFrame(
     {'B': ['B2','B3','B6','B7'],
      'D': ['D2','D3','D6','D7'],
      'F':['F2','F3','F6','F7']},
     index = [2,3,4,7])
result = pd.concat([df1,df4],axis =1,sort=False)
result
# Out:
#      A    B    C    D    B    D    F
# 0   A0   B0   C0   D0  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN
# 2   A2   B2   C2   D2   B2   D2   F2
# 3   A3   B3   C3   D3   B3   D3   F3
# 4  NaN  NaN  NaN  NaN   B6   D6   F6
# 7  NaN  NaN  NaN  NaN   B7   D7   F7

# %%
#inner join
result= pd.concat([df1,df4],axis=1,join='inner')
result
# Out:
#     A   B   C   D   B   D   F
# 2  A2  B2  C2  D2  B2  D2  F2
# 3  A3  B3  C3  D3  B3  D3  F3

# %%
#creating dummy data2
df_a =pd.DataFrame({
    'subject_id':['1','2','3','4','5'],
    'first_name':['Alex','Alla','Andrew','Alan','Alvin'],
    'last_name':['Arnold','Adrian','Aston','Ali','Andre']
})
df_b=pd.DataFrame({
    'subject_id':['4','5','6','7','8'],
    'first_name':['Becky','Bella','Britt','Bradley','Brad'],
    'last_name':['Blakk','Brandon','Bevon','Beverly','Beryl']
})
df_c=pd.DataFrame({
   'subject_id':['1','2','3','4','5','7','8','9','10','11'],
   'test_id':['51','12','2','34','12','14','56','49','13','65']

})

# %%
pd.merge(df_a,df_c , on ='subject_id')
# Out:
#   subject_id first_name last_name test_id
# 0          1       Alex    Arnold      51
# 1          2       Alla    Adrian      12
# 2          3     Andrew     Aston       2
# 3          4       Alan       Ali      34
# 4          5      Alvin     Andre      12

# %%
pd.merge(df_a,df_c,on ='subject_id',how='right')
# Out:
#   subject_id first_name last_name test_id
# 0          1       Alex    Arnold      51
# 1          2       Alla    Adrian      12
# 2          3     Andrew     Aston       2
# 3          4       Alan       Ali      34
# 4          5      Alvin     Andre      12
# 5          7        NaN       NaN      14
# 6          8        NaN       NaN      56
# 7          9        NaN       NaN      49
# 8         10        NaN       NaN      13
# 9         11        NaN       NaN      65

# %%
data_BM=pd.read_csv("bigmart_data.csv")

# %%
data_BM.apply(lambda x:x)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
#accesing the first row
data_BM.apply(lambda x:x[0])
# Out:
# Item_Identifier                          FDA15
# Item_Weight                                9.3
# Item_Fat_Content                       Low Fat
# Item_Visibility                       0.016047
# Item_Type                                Dairy
# Item_MRP                              249.8092
# Outlet_Identifier                       OUT049
# Outlet_Establishment_Year                 1999
# Outlet_Size                             Medium
# Outlet_Location_Type                    Tier 1
# Outlet_Type                  Supermarket Type1
# Item_Outlet_Sales                     3735.138
# dtype: object

# %%
#accesing the first column using index
data_BM.apply(lambda x:x[0],axis=1)
# Out:
# 0       FDA15
# 1       DRC01
# 2       FDN15
# 3       FDX07
# 4       NCD19
#         ...
# 8518    FDF22
# 8519    FDS36
# 8520    NCJ29
# 8521    FDN46
# 8522    DRG01
# Length: 8523, dtype: object

# %%
 #print the column names of data_BM
print(data_BM.columns.to_list())
# Out:
# ['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility', 'Item_Type', 'Item_MRP', 'Outlet_Identifier', 'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type', 'Item_Outlet_Sales']

# %%
data_BM['Item_MRP'][:5]
# Out:
# 0    249.8092
# 1     48.2692
# 2    141.6180
# 3    182.0950
# 4     53.8614
# Name: Item_MRP, dtype: float64

# %%
def clip_price(price):
  if price>200:
    price = 200
  return price

data_BM['Item_MRP'].apply(lambda x:clip_price(x))[:5]
# Out:
# 0    200.0000
# 1     48.2692
# 2    141.6180
# 3    182.0950
# 4     53.8614
# Name: Item_MRP, dtype: float64

# %%
#accesing a column using column name
data_BM.apply(lambda x: x["Item_Fat_Content"], axis=1)
# Out:
# 0       Low Fat
# 1       Regular
# 2       Low Fat
# 3       Regular
# 4       Low Fat
#          ...
# 8518    Low Fat
# 8519    Regular
# 8520    Low Fat
# 8521    Regular
# 8522    Low Fat
# Length: 8523, dtype: object

# %%
def label_encode(city):
  if city=="Tier 1":
    label = 0
  elif city=="Tier 2":
    label = 1
  else:
    label = 2
  return label


data_BM['Outlet_Location_Type'] [:5]
# Out:
# 0    Tier 1
# 1    Tier 3
# 2    Tier 1
# 3    Tier 3
# 4    Tier 3
# Name: Outlet_Location_Type, dtype: object

# %%
data_BM['Outlet_Location_Type'] = data_BM['Outlet_Location_Type'].apply(label_encode)

# %%
data_BM['Outlet_Location_Type'] [:5]
# Out:
# 0    0
# 1    2
# 2    0
# 3    2
# 4    2
# Name: Outlet_Location_Type, dtype: int64

# %%
#using groupby to aggregate data
price_by_item = data_BM.groupby("Item_Type")

price_by_item.first()
# Out:
#                       Item_Identifier  Item_Weight Item_Fat_Content  \
# Item_Type
# Baking Goods                    FDP36       10.395          Regular
# Breads                          FDO23       17.850          Low Fat
# Breakfast                       FDP49        9.000          Regular
# Canned                          FDC14       21.350          Regular
# Dairy                           FDA15        9.300          Low Fat
# Frozen Foods                    FDH17       16.200          Regular
# Fruits and Vegetables           FDX07       19.200          Regular
# Hard Drinks                     DRI11       11.650          Low Fat
# Health and Hygiene              NCB42       11.800          Low Fat
# Household                       NCD19        8.930          Low Fat
# Meat                            FDN15       17.500          Low Fat
# Others                          NCN07       18.500          Low Fat
# Seafood                         FDG33       10.395          Regular
# ...

# %%
price_by_item.Item_MRP.mean()
# Out:
# Item_Type
# Baking Goods             126.380766
# Breads                   140.952669
# Breakfast                141.788151
# Canned                   139.763832
# Dairy                    148.499208
# Frozen Foods             138.503366
# Fruits and Vegetables    144.581235
# Hard Drinks              137.077928
# Health and Hygiene       130.818921
# Household                149.424753
# Meat                     139.882032
# Others                   132.851430
# Seafood                  141.841719
# Snack Foods              146.194934
# Soft Drinks              131.492506
# Starchy Foods            147.838023
# Name: Item_MRP, dtype: float64

# %%
multiple_groups = data_BM.groupby(["Item_Type","Item_Fat_Content"])

multiple_groups.first()
# Out:
#                                Item_Identifier  Item_Weight  Item_Visibility  \
# Item_Type     Item_Fat_Content
# Baking Goods  LF                         FDP24       20.600         0.083133
#               Low Fat                    FDC37       11.100         0.057557
#               Regular                    FDP36       10.395         0.000000
#               low fat                    FDK48        7.445         0.000000
#               reg                        FDF24       15.500         0.025514
# ...                                        ...          ...              ...
# Starchy Foods LF                         FDB11       16.000         0.060797
#               Low Fat                    FDH35       18.250         0.000000
#               Regular                    FDB35       12.300         0.064750
#               low fat                    FDE47       14.150         0.037877
#               reg                        FDF11       10.195         0.017703
#
# ...
